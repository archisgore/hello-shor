# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import numpy as np
from math import gcd
import random

def controlled_modular_exponentiation(circuit, a, power, N, control_qubit, target_qubits):
    """
    Implements controlled modular exponentiation: |x⟩|0⟩ → |x⟩|(a^x) mod N⟩
    This is a simplified version that works for small numbers
    """
    # For small numbers, we can implement this directly
    # For larger numbers, we would need a more sophisticated implementation
    for i in range(len(target_qubits)):
        if (a ** power) % N & (1 << i):
            circuit.ccx(control_qubit, target_qubits[i-1] if i > 0 else control_qubit, target_qubits[i])

def qft(circuit, n):
    """
    Implements the Quantum Fourier Transform on n qubits
    """
    # Apply the QFT
    for i in range(n):
        circuit.h(i)
        for j in range(i + 1, n):
            circuit.cp(np.pi / (2 ** (j - i)), j, i)
    
    # Apply SWAP gates to reverse the order
    for i in range(n // 2):
        circuit.swap(i, n - i - 1)

def shor(N, a=None):
    """
    Implements Shor's algorithm to factorize N
    """
    if N % 2 == 0:
        return "Divisible by 2. No Quantum Circuit needed.", 2, N // 2
    
    if a is None:
        a = random.randint(2, N - 1)
    
    # Check if a and N are coprime
    if gcd(a, N) != 1:
        return f"Random guess a:{a} is not coprime with N:{N}, meaning a shares a non-trivial factor determined by Eucliean algorithm.", gcd(a, N), N // gcd(a, N)
    
    # Number of qubits needed
    n_counting = int(np.ceil(np.log2(N)))
    n_work = int(np.ceil(np.log2(N)))
    
    # Create quantum circuit
    circuit = QuantumCircuit(n_counting + n_work, n_counting)
    
    # Initialize counting qubits in superposition
    for i in range(n_counting):
        circuit.h(i)
    
    # Apply controlled modular exponentiation
    for i in range(n_counting):
        controlled_modular_exponentiation(
            circuit,
            a,
            2**i,
            N,
            i,
            list(range(n_counting, n_counting + n_work))
        )
    
    # Apply inverse QFT
    qft(circuit, n_counting)
    
    # Measure the counting qubits
    circuit.measure(range(n_counting), range(n_counting))
    
    # Run the circuit
    simulator = Aer.get_backend('qasm_simulator')
    compiled_circuit = transpile(circuit, simulator)
    job = simulator.run(compiled_circuit, shots=1024)
    result = job.result()
    counts = result.get_counts()

    # Draw the circuit diagram
    drawing = circuit.draw(output='mpl')
    
    # Find the most common measurement
    measured_value = max(counts, key=counts.get)
    phase = int(measured_value, 2) / (2 ** n_counting)
    
    # Convert phase to fraction
    from fractions import Fraction
    frac = Fraction(phase).limit_denominator(N)
    period = frac.denominator
    
    # If period is odd, try again
    if period % 2 == 1:
        return shor(N)
    
    # Calculate potential factors
    factor1 = gcd(a ** (period // 2) - 1, N)
    factor2 = gcd(a ** (period // 2) + 1, N)
    
    if factor1 == 1 or factor1 == N or factor2 == 1 or factor2 == N:
        return shor(N)
    
    return drawing, factor1, factor2

# %%
if __name__ == "__main__":
    # Test with a small number
    N = 31
    print(f"Factoring {N}...")
    drawing, factor1, factor2 = shor(N)
    print(f"Factors of {N}: {factor1, factor2}") 
    print(drawing)
# Out:
# Factoring 31...
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# Cell In[4], line 5
#       3 N = 31
#       4 print(f"Factoring {N}...")
# ----> 5 drawing, factor1, factor2 = shor(N)
#       6 print(f"Factors of {N}: {factor1, factor2}")
#       7 print(drawing)
#
# Cell In[2], line 60, in shor(N, a)
#      58 # Apply controlled modular exponentiation
#      59 for i in range(n_counting):
# ---> 60     controlled_modular_exponentiation(
#      61         circuit,
#      62         a,
#      63         2**i,
#      64         N,
#      65         i,
#      66         list(range(n_counting, n_counting + n_work))
#      67     )
#      69 # Apply inverse QFT
#      70 qft(circuit, n_counting)
#
# Cell In[2], line 17, in controlled_modular_exponentiation(circuit, a, power, N, control_qubit, target_qubits)
#      15 for i in range(len(target_qubits)):
#      16     if (a ** power) % N & (1 << i):
# ---> 17         circuit.ccx(control_qubit, target_qubits[i-1] if i > 0 else control_qubit, target_qubits[i])
#
# File ~/github/archisgore/hello-shor/.venv/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:5689, in QuantumCircuit.ccx(self, control_qubit1, control_qubit2, target_qubit, ctrl_state)
#    5687 # if the control state is |11> use the fast Rust version of the gate
#    5688 if ctrl_state is None or ctrl_state in ["11", 3]:
# -> 5689     return self._append_standard_gate(
#    5690         StandardGate.CCXGate,
#    5691         [control_qubit1, control_qubit2, target_qubit],
#    5692         (),
#    5693     )
#    5695 from .library.standard_gates.x import CCXGate
#    5697 return self.append(
#    5698     CCXGate(ctrl_state=ctrl_state),
#    5699     [control_qubit1, control_qubit2, target_qubit],
#    5700     [],
#    5701     copy=False,
#    5702 )
#
# File ~/github/archisgore/hello-shor/.venv/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:2393, in QuantumCircuit._append_standard_gate(self, op, qargs, params, label)
#    2391 instructions = InstructionSet(resource_requester=circuit_scope.resolve_classical_resource)
#    2392 for qarg, _ in Gate.broadcast_arguments(op, expanded_qargs, []):
# -> 2393     self._check_dups(qarg)
#    2394     instruction = CircuitInstruction.from_standard(op, qarg, params, label=label)
#    2395     circuit_scope.append(instruction, _standard_gate=True)
#
# File ~/github/archisgore/hello-shor/.venv/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:3311, in QuantumCircuit._check_dups(self, qubits)
#    3309 def _check_dups(self, qubits: Sequence[Qubit]) -> None:
#    3310     """Raise exception if list of qubits contains duplicates."""
# -> 3311     CircuitData._check_dups(qubits)
#
# CircuitError: 'duplicate qubit arguments'
